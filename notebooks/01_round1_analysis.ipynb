# %% [markdown]
# # Round 1 Analysis
#
# Reproduces the figures published in *"Opportunities and Limitations of GenAI in RE: Viewpoints from Practice"* (REFSQ 2026) from the round-1 survey data (`data/round1/raw.csv`). All analysis logic lives in `src/genai_re_survey/`; this notebook just loads the data and calls it.

# %%
from genai_re_survey import loading, reports, schema

# %%
df = loading.load_round1()
df.shape
# Out:
# (109, 202)

# %% [markdown]
# ## Generate all figures
#
# Demographics + RQ1–RQ4, saved to `figures/round1/`.

# %%
reports.generate_round_report(df, round_name="Round 1", outdir="../figures/round1")
# Out:
# === Round 1: Respondent demographics ===
#
# Years of RE experience (n=109)
#   none / new to RE: 5 (5%)
#   < 2 years: 10 (9%)
#   3-5 years: 17 (16%)
#   6-10 years: 22 (20%)
#   > 10 years: 55 (50%)
#
# Organization type (n=109)
#   Industry - Micro enterprise (up to 10 employees): 5 (5%)
#   Industry - Small enterprise (10-49 employees): 7 (6%)
#   Industry - Medium-sized enterprise (50-249 employees): 16 (15%)
#   Industry - Large enterprise (at least 250 employees): 66 (61%)
#   Research-technology transfer: 7 (6%)
#   University / Research: 2 (2%)
#   Other: 6 (6%)
#
# Role / position (n=109, % of respondents who selected — multi-select, need not sum to 100%)
#   Requirements Engineer: 57 (52%)
#   Business Analyst: 33 (30%)
#   Other: 29 (27%)
#   Product Owner: 19 (17%)
#   Project Manager: 19 (17%)
#   Technical Leader: 12 (11%)
#   Software Developer: 11 (10%)
#   Software Architect: 8 (7%)
#   UI / UX Designer: 5 (5%)
#
# ...
