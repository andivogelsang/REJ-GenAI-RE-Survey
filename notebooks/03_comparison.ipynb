# %% [markdown]
# # Round 1 vs. Round 2 Comparison
#
# Loads both rounds, reports how their column schemas differ after `genai_re_survey.loading` normalizes them, then renders paired/grouped comparison figures for every RQ1–RQ4 chart plus two general GenAI-usage demographic charts (tool-usage frequency, experience duration).

# %%
from genai_re_survey import loading, reports, schema

# %%
df1 = loading.load_round1()
df2 = loading.load_round2()
df1.shape, df2.shape
# Out:
# ((109, 202), (69, 200))

# %% [markdown]
# ## Schema diff
#
# What's left after normalization: shared items produce paired bars; anything listed below is round-specific and shown as such (e.g. round 2's new "which GenAI tools do you use" question has no round-1 counterpart).

# %%
_ = schema.diff_schemas(df1, df2)
# Out:
# Bracket labels: 115 shared, 0 round1-only, 0 round2-only
# Core questions: 28 shared, 0 round1-only, 4 round2-only
#   round2-only: 'Date last action'
#   round2-only: 'Date started'
#   round2-only: 'Did you participate in our previous survey as well?'
#   round2-only: 'Which GenAI tools do you use primarily in the context of your work?'

# %% [markdown]
# ## Generate all comparison figures
#
# Saved to `figures/comparison/`.

# %%
reports.generate_comparison_report(
    df1, df2,
    outdir="../figures/comparison",
    round1_label="Round 1",
    round2_label="Round 2",
)
# Out:
# === Round 1 vs Round 2: Respondent demographics ===
#
# Years of RE experience (Round 1 n=109, Round 2 n=69)
#   none / new to RE: Round 1 5 (5%) | Round 2 8 (12%)
#   < 2 years: Round 1 10 (9%) | Round 2 5 (7%)
#   3-5 years: Round 1 17 (16%) | Round 2 9 (13%)
#   6-10 years: Round 1 22 (20%) | Round 2 15 (22%)
#   > 10 years: Round 1 55 (50%) | Round 2 32 (46%)
#
# Organization type (Round 1 n=109, Round 2 n=69)
#   Industry - Micro enterprise (up to 10 employees): Round 1 5 (5%) | Round 2 7 (10%)
#   Industry - Small enterprise (10-49 employees): Round 1 7 (6%) | Round 2 10 (14%)
#   Industry - Medium-sized enterprise (50-249 employees): Round 1 16 (15%) | Round 2 7 (10%)
#   Industry - Large enterprise (at least 250 employees): Round 1 66 (61%) | Round 2 22 (32%)
#   Research-technology transfer: Round 1 7 (6%) | Round 2 3 (4%)
#   University / Research: Round 1 2 (2%) | Round 2 13 (19%)
#   Other: Round 1 6 (6%) | Round 2 7 (10%)
#
# Role / position (Round 1 n=109, Round 2 n=69, % who selected)
#   Requirements Engineer: Round 1 57 (52%) | Round 2 34 (49%)
#   Business Analyst: Round 1 33 (30%) | Round 2 23 (33%)
#   Other: Round 1 29 (27%) | Round 2 22 (32%)
#   Product Owner: Round 1 19 (17%) | Round 2 13 (19%)
#   Project Manager: Round 1 19 (17%) | Round 2 14 (20%)
#   Technical Leader: Round 1 12 (11%) | Round 2 6 (9%)
#   Software Developer: Round 1 11 (10%) | Round 2 12 (17%)
#   Software Architect: Round 1 8 (7%) | Round 2 7 (10%)
#   UI / UX Designer: Round 1 5 (5%) | Round 2 5 (7%)
#
# Region (Round 1 n=109, Round 2 n=69, % who selected)
#   Europe: Round 1 99 (91%) | Round 2 56 (81%)
#   Asia: Round 1 8 (7%) | Round 2 8 (12%)
#   North America: Round 1 4 (4%) | Round 2 8 (12%)
#   South America: Round 1 3 (3%) | Round 2 7 (10%)
#   Africa: Round 1 2 (2%) | Round 2 1 (1%)
#   Australia - New Zealand (Oceania): Round 1 1 (1%) | Round 2 2 (3%)
#
# Application domain (Round 1 n=109, Round 2 n=69, % who selected)
#   IT / Software: Round 1 73 (67%) | Round 2 53 (77%)
#   Automotive: Round 1 28 (26%) | Round 2 11 (16%)
#   Other: Round 1 20 (18%) | Round 2 15 (22%)
#   Banking / Insurances: Round 1 19 (17%) | Round 2 12 (17%)
#   Education: Round 1 14 (13%) | Round 2 14 (20%)
#   Chemicals, pharmaceuticals, medical technology: Round 1 12 (11%) | Round 2 5 (7%)
#   Research: Round 1 12 (11%) | Round 2 18 (26%)
#   Transport and Logistics: Round 1 10 (9%) | Round 2 3 (4%)
#   Mechanical Engineering: Round 1 7 (6%) | Round 2 2 (3%)
#   Telecommunication: Round 1 5 (5%) | Round 2 8 (12%)
#   Aerospace: Round 1 3 (3%) | Round 2 2 (3%)
#   Defense: Round 1 3 (3%) | Round 2 6 (9%)
#   Trade: Round 1 2 (2%) | Round 2 2 (3%)
#
# RE-discipline self-assessed experience — Elicitation (Round 1 n=109, Round 2 n=69)
#   No Experience: Round 1 5 (5%) | Round 2 4 (6%)
#   Beginner: Round 1 7 (6%) | Round 2 10 (14%)
#   Intermediate: Round 1 23 (21%) | Round 2 12 (17%)
#   Advanced: Round 1 43 (39%) | Round 2 22 (32%)
#   Expert: Round 1 31 (28%) | Round 2 21 (30%)
#
# RE-discipline self-assessed experience — Analysis and Negotiation (Round 1 n=109, Round 2 n=69)
#   No Experience: Round 1 5 (5%) | Round 2 4 (6%)
#   Beginner: Round 1 6 (6%) | Round 2 8 (12%)
#   Intermediate: Round 1 21 (19%) | Round 2 12 (17%)
#   Advanced: Round 1 44 (40%) | Round 2 23 (33%)
#   Expert: Round 1 33 (30%) | Round 2 22 (32%)
#
# RE-discipline self-assessed experience — Specification (Round 1 n=109, Round 2 n=69)
#   No Experience: Round 1 2 (2%) | Round 2 1 (1%)
#   Beginner: Round 1 9 (8%) | Round 2 10 (14%)
#   Intermediate: Round 1 21 (19%) | Round 2 10 (14%)
#   Advanced: Round 1 40 (37%) | Round 2 26 (38%)
#   Expert: Round 1 37 (34%) | Round 2 22 (32%)
#
# RE-discipline self-assessed experience — Validation (Round 1 n=109, Round 2 n=69)
#   No Experience: Round 1 4 (4%) | Round 2 3 (4%)
#   Beginner: Round 1 10 (9%) | Round 2 10 (14%)
#   Intermediate: Round 1 26 (24%) | Round 2 20 (29%)
#   Advanced: Round 1 43 (39%) | Round 2 18 (26%)
#   Expert: Round 1 26 (24%) | Round 2 18 (26%)
#
# RE-discipline self-assessed experience — Management (Round 1 n=109, Round 2 n=69)
#   No Experience: Round 1 5 (5%) | Round 2 4 (6%)
#   Beginner: Round 1 9 (8%) | Round 2 9 (13%)
#   Intermediate: Round 1 22 (20%) | Round 2 11 (16%)
#   Advanced: Round 1 44 (40%) | Round 2 29 (42%)
#   Expert: Round 1 29 (27%) | Round 2 16 (23%)
#
# GenAI tool usage frequency (Round 1 n=109, Round 2 n=69)
#   Never used: Round 1 4 (4%) | Round 2 2 (3%)
#   Tried once: Round 1 9 (8%) | Round 2 3 (4%)
#   At least once a month: Round 1 18 (17%) | Round 2 5 (7%)
#   At least once a week: Round 1 34 (31%) | Round 2 16 (23%)
#   Daily: Round 1 44 (40%) | Round 2 42 (61%)
#   Other: Round 1 0 (0%) | Round 2 1 (1%)
#
# GenAI experience duration (Round 1 n=109, Round 2 n=69)
#   No Experience at all: Round 1 30 (28%) | Round 2 2 (3%)
#   Less than 1 year: Round 1 41 (38%) | Round 2 17 (25%)
#   1-2 years: Round 1 34 (31%) | Round 2 30 (43%)
#   3-4 years: Round 1 3 (3%) | Round 2 16 (23%)
#   More than 4 years: Round 1 1 (1%) | Round 2 4 (6%)
# === Round 1 vs Round 2: significance testing (Benjamini-Hochberg FDR, alpha=0.05) ===
#
# RQ1: Usage by RE discipline (6 items tested)
#   Management: odds_ratio=0.19, p=0.0003, q=0.0016 (n1=64, n2=48)
#
# RQ2: Prevention reasons (13 items tested)
#   Limited scope of AI applications in RE: odds_ratio=11.36, p=0.0031, q=0.0408 (n1=85, n2=50)
#
# RQ2: Perceived threats (16 items tested)
#   no items significant after FDR correction
#
# RQ4: Skills + training (18 items tested)
#   no items significant after FDR correction
#
# Demographics: Role / position (9 items tested)
#   no items significant after FDR correction
#
# Demographics: Region (6 items tested)
#   no items significant after FDR correction
#
# Demographics: Application domain (13 items tested)
#   no items significant after FDR correction
#
# Demographics: Organization type (7 items tested)
#   University / Research: odds_ratio=0.08, p=0.0001, q=0.0007 (n1=109, n2=69)
#   Industry - Large enterprise (at least 250 employees): odds_ratio=3.28, p=0.0002, q=0.0008 (n1=109, n2=69)
#
# RQ3: Elicitation (18 items tested)
#   no items significant after FDR correction
#
# RQ3: Analysis (18 items tested)
#   no items significant after FDR correction
#
# RQ3: Specification and Modeling (12 items tested)
#   no items significant after FDR correction
#
# RQ3: Validation and QA (16 items tested)
#   Planning and conducting reviews or inspections (Usefulness): rank_biserial_r=0.48, p=0.0001, q=0.0017 (n1=44, n2=39)
#   Identification of unnecessary / incorrect requirements (Usefulness): rank_biserial_r=0.37, p=0.0019, q=0.0155 (n1=50, n2=39)
#   Validation against stakeholder needs (Usefulness): rank_biserial_r=0.32, p=0.0085, q=0.0399 (n1=46, n2=42)
#   Identification of incomplete / missing requirements (Usefulness): rank_biserial_r=0.30, p=0.0100, q=0.0399 (n1=51, n2=41)
#
# RQ3: Requirements Management (10 items tested)
#   Requirements process assessment (Usefulness): rank_biserial_r=0.44, p=0.0007, q=0.0073 (n1=42, n2=34)
#
# Demographics: Experience (ordinal) (6 items tested)
#   no items significant after FDR correction
#
# Bracket labels: 115 shared, 0 round1-only, 0 round2-only
# Core questions: 28 shared, 0 round1-only, 4 round2-only
#   round2-only: 'Date last action'
#   round2-only: 'Date started'
#   round2-only: 'Did you participate in our previous survey as well?'
#   round2-only: 'Which GenAI tools do you use primarily in the context of your work?'
# {'bracket_labels_shared': ['AI-supported Requirements Analysis &amp; Negotiation',
#   'AI-supported Requirements Elicitation',
#   'AI-supported Requirements Management',
#   'AI-supported Requirements Specification / Requirements Modeling',
#   'AI-supported Requirements Validation / Quality Assurance',
#   'Aerospace',
#   'Africa',
#   'Analysis of as-is situations / as-is scenarios',
#   'Analysis of elicited data(e.g., gained from interviews, surveys, field studies,document analysis)',
#   'Asia',
#   'Australia - New Zealand (Oceania)',
#   'Automotive',
#   'Banking / Insurances ',
#   'Bias in AI models',
#   'Blended learning programs',
#   'Business Analyst',
#   'Case study analysis and group discussions',
#   'Change impact analysis',
#   'Change management',
#   'Chemicals, pharmaceuticals, medical technology',
#   'Comment',
#   'Community of practice',
#   'Conferences ',
#   'Confidentiality',
#   'Configuration management (e.g., version control, document management)',
#   'Conflict identification and resolution',
#   'Contextual understanding and ambiguity handling',
#   'Cost and resource constraints',
#   'Creating diagrams (e.g., UML models)',
#   'Creating document structures',
#   'Creating use case descriptions',
#   'Creation of test cases(e.g., to verify testability)',
#   'Creativity / ideation(e.g., generating (innovative) ideas / requirements)',
#   'Cultural resistance and organizational inertia',
#   'Data quality and availability',
#   'Defense',
#   'Defining acceptance criteria',
#   'Drafting specifications',
#   'Education',
#   'Ethical and legal concerns',
#   'Ethical and legal concerns (e.g., data privacy)',
#   'Europe',
#   'Fear of job displacement',
#   'Feasibility analysis / Risk analysis',
#   'Formulating requirements',
#   'Gap analysis',
#   'Hackathons',
#   'Hallucinations(i.e., generated output that is nonsensical, inaccurate or not based on training data)',
#   "I don't see any limitations / threats",
#   'IT / Software',
#   'Identification / analysis of stakeholders and their needs(e.g., generating personas)',
#   'Identification of incomplete / missing requirements',
#   'Identification of inconsistencies',
#   'Identification of requirements that are difficult to understand(e.g., due to ambiguities)',
#   'Identification of unnecessary / incorrect requirements',
#   'Insufficient quality / availability of input data ',
#   'Integration challenges (i.e., integrating AI in existing RE processes)',
#   'Lack of awareness or knowledge',
#   'Lack of support / tools',
#   'Lack of time',
#   'Lack of transparency and explainability',
#   'Limited scope of AI applications in RE',
#   'Loss of human intuition and judgement',
#   'Maintain requirements traceability',
#   'Maintenance and adaptation (i.e., keeping the AI models up to date)',
#   'Mechanical Engineering',
#   'Mentoring programs',
#   'Newsletter',
#   'North America',
#   'Online courses and webinars',
#   'Other',
#   'Other comment',
#   'Over-reliance on AI',
#   'Performing domain analysis',
#   'Planning and conducting reviews or inspections',
#   'Preparation of field studies / observations',
#   'Preparation of surveys / interview guidelines',
#   'Preparation of workshops / focus groups',
#   'Product Owner',
#   'Project Manager',
#   'Prototyping for requirements elicitation',
#   'Requirements Analysis &amp; Negotiation',
#   'Requirements Elicitation',
#   'Requirements Engineer',
#   'Requirements Management',
#   'Requirements Specification / Requirements Modeling',
#   'Requirements Validation / Quality Assurance',
#   'Requirements categorization and grouping',
#   'Requirements prioritization',
#   'Requirements process assessment(e.g., auditing)',
#   'Requirements refinement and clarification',
#   'Requirements tracking and monitoring',
#   'Research',
#   'Resistance to adoption',
#   'Scalability issues',
#   'Scale 1',
#   'Scale 2',
#   'Software Architect',
#   'Software Developer',
#   'South America',
#   'Stakeholder alignment and consensus building',
#   'Technical Leader',
#   'Telecommunication',
#   'Trade',
#   'Trade-off analysis',
#   'Transport &amp; Logistics',
#   'UI / UX Designer',
#   'Uncertainty about ROI (Return on Investment)',
#   'Unclear or inconsistent results',
#   'Unclear, inconsistent, low-quality results',
#   'Using AI is forbidden by my organization',
#   'Validation against business objectives',
#   'Validation against stakeholder needs',
#   'Workshops, tutorials and hands-on labs',
#   '“Classical Training” (e.g., Classroom Training, Face-2-Face Training)'],
#  'bracket_labels_round1_only': [],
#  'bracket_labels_round2_only': [],
#  'core_questions_shared': ['Are there any further analysis- / negotiation-related tasks or goals for which GenAI could be useful / be harmful?If yes, please list them here and assess the degree of usefulness / harmfulness of AI.\xa0',
#   'Are there any further comments, remarks or ideas that you would like to share with us?',
#   'Are there any further elicitation-related tasks or goals for which GenAI could be useful / be harmful?If yes, please list them here and assess the degree of usefulness / harmfulness of AI.\xa0',
#   'Are there any further management-related tasks or goals for which GenAI could be useful / be harmful?If yes, please list them here and assess the degree of usefulness / harmfulness of AI.\xa0',
#   'Are there any further specification- / modeling-related tasks or goals for which GenAI could be useful / be harmful?If yes, please list them here and assess the degree of usefulness / harmfulness of AI.\xa0',
#   'Are there any further validation- / quality-assurance-related tasks or goals for which GenAI could be useful / be harmful?If yes, please list them here and assess the degree of usefulness / harmfulness of AI.\xa0',
#   'Date submitted',
#   'Do you think the skill set of requirements engineers will need to change as AI becomes more prevalent in requirements engineering?If yes, please specify which\xa0skills you believe will be affected or will need to change in the comments field.  \xa0 ',
#   'Have you also experienced situations that prevented you from using GenAI in RE-related disciplines?\xa0',
#   'How many years of professional experience do you have in Requirements Engineering (RE)? ',
#   'Last page',
#   'Response ID',
#   'Seed',
#   'Start language',
#   'What negative experience did you gain when using GenAI for REQUIREMENTS ANALYSIS &amp; NEGOTIATION?',
#   'What negative experience did you gain when using GenAI for REQUIREMENTS ELICITATION?',
#   'What negative experience did you gain when using GenAI for REQUIREMENTS MANAGEMENT?',
#   'What negative experience did you gain when using GenAI for REQUIREMENTS SPECIFICATION / REQUIREMENTS MODELING?',
#   'What negative experience did you gain when using GenAI for REQUIREMENTS VALIDATION / QUALITY ASSURANCE?',
#   'What positive experience did you gain when using AI for REQUIREMENTS MANAGEMENT?',
#   'What positive experience did you gain when using GenAI for REQUIREMENTS ANALYSIS &amp; NEGOTIATION?',
#   'What positive experience did you gain when using GenAI for REQUIREMENTS ELICITATION?',
#   'What positive experience did you gain when using GenAI for REQUIREMENTS SPECIFICATION / REQUIREMENTS MODELING?',
#   'What positive experience did you gain when using GenAI for REQUIREMENTS VALIDATION / QUALITY ASSURANCE?',
#   'Which of the following organization / business types\xa0best describes your organization?',
#   'genai_experience_duration',
#   'genai_tool_usage_frequency',
#   'used_genai_for_re'],
#  'core_questions_round1_only': [],
#  'core_questions_round2_only': ['Date last action',
#   'Date started',
#   'Did you participate in our previous survey as well?',
#   'Which GenAI tools do you use primarily in the context of your work?']}
