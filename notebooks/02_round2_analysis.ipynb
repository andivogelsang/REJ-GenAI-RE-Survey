# %% [markdown]
# # Round 2 Analysis
#
# Same analysis as `01_round1_analysis.ipynb`, run against the second wave of survey responses (`data/round2/raw.csv`) collected for the journal extension.

# %%
from genai_re_survey import loading, reports, schema

# %%
df = loading.load_round2()
df.shape
# Out:
# (69, 200)

# %% [markdown]
# ## Generate all figures
#
# Demographics + RQ1–RQ4, saved to `figures/round2/`.

# %%
reports.generate_round_report(df, round_name="Round 2", outdir="../figures/round2")
# Out:
# === Round 2: Respondent demographics ===
#
# Years of RE experience (n=69)
#   none / new to RE: 8 (12%)
#   < 2 years: 5 (7%)
#   3-5 years: 9 (13%)
#   6-10 years: 15 (22%)
#   > 10 years: 32 (46%)
#
# Organization type (n=69)
#   Industry - Micro enterprise (up to 10 employees): 7 (10%)
#   Industry - Small enterprise (10-49 employees): 10 (14%)
#   Industry - Medium-sized enterprise (50-249 employees): 7 (10%)
#   Industry - Large enterprise (at least 250 employees): 22 (32%)
#   Research-technology transfer: 3 (4%)
#   University / Research: 13 (19%)
#   Other: 7 (10%)
#
# Role / position (n=69, % of respondents who selected — multi-select, need not sum to 100%)
#   Requirements Engineer: 34 (49%)
#   Business Analyst: 23 (33%)
#   Other: 22 (32%)
#   Project Manager: 14 (20%)
#   Product Owner: 13 (19%)
#   Software Developer: 12 (17%)
#   Software Architect: 7 (10%)
#   Technical Leader: 6 (9%)
#   UI / UX Designer: 5 (7%)
#
# Region (n=69, % of respondents who selected — multi-select, need not sum to 100%)
#   Europe: 56 (81%)
#   Asia: 8 (12%)
#   North America: 8 (12%)
#   South America: 7 (10%)
#   Australia - New Zealand (Oceania): 2 (3%)
#   Africa: 1 (1%)
#
# Application domain (n=69, % of respondents who selected — multi-select, need not sum to 100%)
#   IT / Software: 53 (77%)
#   Research: 18 (26%)
#   Other: 15 (22%)
#   Education: 14 (20%)
#   Banking / Insurances: 12 (17%)
#   Automotive: 11 (16%)
#   Telecommunication: 8 (12%)
#   Defense: 6 (9%)
#   Chemicals, pharmaceuticals, medical technology: 5 (7%)
#   Transport and Logistics: 3 (4%)
#   Aerospace: 2 (3%)
#   Mechanical Engineering: 2 (3%)
#   Trade: 2 (3%)
#
# RE-discipline self-assessed experience — Elicitation (n=69)
#   No Experience: 4 (6%)
#   Beginner: 10 (14%)
#   Intermediate: 12 (17%)
#   Advanced: 22 (32%)
#   Expert: 21 (30%)
#
# RE-discipline self-assessed experience — Analysis and Negotiation (n=69)
#   No Experience: 4 (6%)
#   Beginner: 8 (12%)
#   Intermediate: 12 (17%)
#   Advanced: 23 (33%)
#   Expert: 22 (32%)
#
# RE-discipline self-assessed experience — Specification (n=69)
#   No Experience: 1 (1%)
#   Beginner: 10 (14%)
#   Intermediate: 10 (14%)
#   Advanced: 26 (38%)
#   Expert: 22 (32%)
#
# RE-discipline self-assessed experience — Validation (n=69)
#   No Experience: 3 (4%)
#   Beginner: 10 (14%)
#   Intermediate: 20 (29%)
#   Advanced: 18 (26%)
#   Expert: 18 (26%)
#
# RE-discipline self-assessed experience — Management (n=69)
#   No Experience: 4 (6%)
#   Beginner: 9 (13%)
#   Intermediate: 11 (16%)
#   Advanced: 29 (42%)
#   Expert: 16 (23%)
#
# GenAI tool usage frequency (n=69)
#   Never used: 2 (3%)
#   Tried once: 3 (4%)
#   At least once a month: 5 (7%)
#   At least once a week: 16 (23%)
#   Daily: 42 (61%)
#   Other: 1 (1%)
#
# GenAI experience duration (n=69)
#   No Experience at all: 2 (3%)
#   Less than 1 year: 17 (25%)
#   1-2 years: 30 (43%)
#   3-4 years: 16 (23%)
#   More than 4 years: 4 (6%)
#
# Participated in previous survey (n=69)
#   Yes: 6 (9%)
#   No: 54 (78%)
#   I don't remember: 9 (13%)
# === Round 2: GenAI usage — free-text comments ===
#
# === Round 2: Training interest — free-text comments ===
#
# --- For which of the following activities would you like to receive training (if any)?For each activity you selected, please provide examples of training topics that would interest you. [AI-supported Requirements Elicitation][Comment] ---
# 8: Prompt-Design, User Stories generieren, Prüfung nach vollständigkeit von Anforderungen, Erstellung von Persona
# 16: Identify sources, create requirements from available documents and prioritize them according to the project.
# 27: AI-assisted stakeholder interviews, AI for workshop facilitation, Generating interview questions, Extracting requirements from documents, emails and meeting transcripts, AI for Voice of Customer analysis
# 31: Grounding to real world
# 52: Trimming GenAI tools for domain specific knowledge
# 55: How to specifically use an AI to synthesize the requirements from stakeholders without lossing the relevant informations in them.
#
# --- For which of the following activities would you like to receive training (if any)?For each activity you selected, please provide examples of training topics that would interest you. [AI-supported Requirements Analysis &amp; Negotiation][Comment] ---
# 8: Qualitätscheck der Anforderung, Widersprüche in der Anforderung erkennen
# 27: Detecting requirement conflicts and inconsistencies, AI-assisted prioritization techniques, Impact analysis using AI, Trade-off analysis, AI-supported negotiation preparation
#
# --- For which of the following activities would you like to receive training (if any)?For each activity you selected, please provide examples of training topics that would interest you. [AI-supported Requirements Specification / Requirements Modeling][Comment] ---
# 8: Automatisierte Akzeptanzkriterien nach Gherkin, visuelle Modellierung der Texte, Prototyping
# 11: implemetation in daily process
# 16: Modeling can be a really great pro in the use of AI. Specification ca  help the RE in 'getting the work done'. How to prioritize the work. How to make requirements complete.
# 27: Writing high-quality requirements with AI, User Stories to System Requirements transformation, SysML/UML model generation, Requirements templates and prompt engineering, AI-assisted requirements
# 28: prompting templates, QA on generated output
# 31: Completeness of Models acc. to ISO/IEC 14143
# 40: Using GenAI to create and refine user stories, use cases, acceptance criteria, process models, and diagrams while ensuring consistency, traceability, and reducing hallucinations.
#
# --- For which of the following activities would you like to receive training (if any)?For each activity you selected, please provide examples of training topics that would interest you. [AI-supported Requirements Validation / Quality Assurance][Comment] ---
# 8: Prüfung der Konsistenz  von z.B. Begrifflichkeiten
# 27: Automatic quality checking against INCOSE/ISO guidelines, Detecting ambiguity, incompleteness and inconsistencies, AI-generated review checklists, Requirements verification support, Traceability validation
# 54: Creating an automated testing suite that cover important scenarios and code that's easy to understand.
# 68: Reliable automation
#
# --- For which of the following activities would you like to receive training (if any)?For each activity you selected, please provide examples of training topics that would interest you. [AI-supported Requirements Management][Comment] ---
# 25: AI-assisted BPMN, UML, and domain modeling, traceability, impact analysis, quality assurance, and AI integration into requirements engineering.
# 27: AI-assisted requirements lifecycle management, Automatic classification and tagging, Change impact analysis, AI for ReqIF and DOORS/Polarion integration, Knowledge management and semantic search
# 31: Completeness of Requirements, QFD in RE
# 54: Ways of using AI for Requirements Management.
# 55: Effective traceability management using AI
# 68: Tracebility and keeping track of Requirements
#
# === Round 2: Skill set change — free-text comments ===
#
# --- Do you think the skill set of requirements engineers will need to change as AI becomes more prevalent in requirements engineering?If yes, please specify which skills you believe will be affected or will need to change in the comments field.     [Comment] ---
# 8: Kompetenz von Prompt Engineering wird wichtig.
# Halluzinationen müssen erkannt werden.
# Gesamtüberblick muss beibehalten werden.
# 9: We need to learn how we can remain the owner of ideas, intuition and creativity.
# 15: AI will force more and more to learn as you go.
# 16: We can make more use of LLM. This is now not available anywhere.
# 18: Quality
# 20: Empathy and social skills
# 25: AI will likely accelerate many requirements engineering activities, allowing requirements engineers to analyze information, produce artifacts, and iterate much faster. This means that engineers will need to focus less on manually creating documentation and more on validating AI-generated results, asking the right questions, making sound decisions, and critically evaluating the quality and correctness of AI outputs. Strong domain knowledge, analytical thinking, and the ability to collaborate effectively with AI tools will become increasingly important.
# 26: Since GenAI will generaye anything for you, you must know "what do you want exactly" with clarity
# 27: Requirements engineers will need stronger AI literacy, prompt engineering, critical thinking, AI output validation, data and model governance, systems thinking, semantic search and knowledge management, AI-assisted requirements elicitation, analysis, specification, verification and traceability, AI tool integration, automation design, ethical and responsible AI usage, collaboration with AI agents, and the ability to focus more on decision-making, stakeholder communication, negotiation, and strategic thinking rather than manual documentation.
# 28: much more AI skills; more QA & validation skills; reading & writing will be done more & more by AI
# 30: More “programming” skills are needed to validate the input or output (playwright, python) as before.
# 31: Detect Hallucinations
# Grounding requirements
# Quality Function Deployment in RE
# 32: Technical, methodological, and organizational/managerial/governmental skills of using GenAI in a effective and ethical manner
# 33: More nuanced language skills required - beyond technical language.
# Healthy moral compass.
# 40: The skill set of requirements engineers needs to evolve. They must learn prompt engineering and understand how to use GenAI effectively at the right stages of the requirements engineering process. This will allow them to support analysis, negotiation, specification, and modeling without introducing unnecessary risks. The goal is to use GenAI where it creates real value for the project, while keeping human judgment, stakeholder validation, and business context at the center of the process.
# 42: Requirements engineers should be trained to avoid overreliance and ensure a sceptical treatment of AI findings. They now require bias detection, alucination and non-determinism skills to use AI in RE.
# 44: analysis, logical thinking, recognizing good and bad (fake/not fake)
# 45: Skill to determine which tasks can be delegated to GenAI and which tasks that need direct human involvement. In addition, skill to be able to prompt effectively ensure that the outcomes resulted from GenAI are evidence-grounded
# 46: Modelling, Documentation
# 47: RE Engineers should be good with the Data. So in future they should develop competency in Data Engineering as it would be the founding block upon which LLMs are built
# 50: judgement and control mechanism
# 54: I don't think the skill set will change, but that the current skill set will be even more relevant as you need to assess the AI output, make it easy to understand, and handle hallucinations.
# 56: I think it will be less about following templates / admin work.  More about business understanding
# 58: AI evolution,  AI contiuous development, AI maintenance and services
# 59: AI is just another tool for the experienced Req. Engineer
# 64: Over-dependence on AI has a tendency to lose the analytical and logical faculty/thinking of a Requirements Engineer. Hence, the RE should be more skeptical and investigative
# 68: I think requirements engineers are generally well equipped to work with AI. The challenge will be to stay up to date with the development of the various models and not to loose common sense and the ability to think on their own.
#
# === Round 2: Organization type — 'Other' free text ===
#
# --- Which of the following organization / business types best describes your organization? [Other] ---
# 7: Bund
# 13: Governamental
# 16: Gouvernement
# 24: Public
# 28: Consulting/Coaching/Training
# 42: Government
# 58: Government > 1800 emoloyees
#
# === Round 2: Role / position — 'Other' free text ===
#
# --- What is your current role or position in your organization?  [Other] ---
# 0: Feature Owner
# 1: Executive Director
# 3: Lecturer
# 8: Tester
# 12: Executive Director
# 13: System Analyst
# 18: Research Associate
# 22: DevOps
# 24: lecturer
# 26: Technical Program Manager
# 30: Test Manager
# 31: Company Owner
# 32: Process Engineer (Requirements Processes) and Internal Coach
# 33: Professor
# 35: Student
# 43: Prof
# 45: Lecturer and researcher
# 53: Transformation Manager
# 55: Researcher
# 57: Solution Architect
# 61: Trainer, Consultant
# 63: Solutions Consultant
#
# === Round 2: Primary GenAI tools used — free text (round 2 only) ===
#
# --- Which GenAI tools do you use primarily in the context of your work? ---
# 0: ChatGPT, Codex, Rovo
# 1: Mistral
# 2: Chat GPT, claude, Gemini, Perplexity
# 3: Gpt
# 4: API Calls of various LLMs & SLMs ( e.g. Claude, OpenAI, BERT, etc.)
# 5: IpenAI
# 6: ChatGPT, Gemini, Claude
# 7: Antrophic
# 8: Copilot, Gemini, Claude
# 9: Chat GPT, Claude Chat, Claude Code, Mistral Vibe, Mistral Chat, Rovo, Notebook LM
# 10: chatgpt,claude,gemini
# 11: Anthropic Claude, Atlassian Rovo
# 12: Mistral
# 13: Gemini, gpt, Claude
# 14: ChatGPT and Claude
# 15: GitHub copilot and more recently Claude code
# 16: Copilot
# 17: Microsoft Copilot
# 20: Gemini, ChatGTP
# 22: Claude, Perplexity, Gemini
# 23: WeaverAI, Claude Code
# 24: chat gpt
# 25: codex and Google antigravity (for work)
# 26: Claude, Perplexity, DeepSeek, JIRA AI, Copilot
# 27: Copilot, Claude
# 28: CoPilot, Claude, local models
# 30: ChatGPT, Mistral, Copilot, Qwen
# 31: Perplexity
# 32: Anthropic Claude, DeepL
# 33: ChatGPT
# 35: Claude
# 36: Claude
# 37: Claude
# 38: AI chatbots
# 39: Codex, Claude, Llama, Gemini, ChatGPT
# 40: GPT, Gemini, Claude, AI Pilot
# 41: ChatGPT, Copilot, Gemini, Claude Code
# 42: Microsoft Copilot, Chat GPT
# 43: Claude Code, Claude Cowork, ChatGPT Chat
# 44: ChatGPT, Claude, Gemini, in built in some tools
# 45: ChatGPT
# 46: Codex, GPT, Copilot, Claude
# 47: Claude, ChatGPT, Gemini
# 48: Claude, Geminia and ChatGPT
# 49: Claude Code and Glean
# 50: Chatbots, storywise
# 51: Copilot/ adjusted Chat gpt
# 52: Copilot, Rovo (Atlassian), Perplexity, ChatGPT
# 53: Claude, Rovo
# 54: Claude Code, Glean, Gemini
# 55: Claude Code, ChatGpt Education
# 56: Microsoft Co-pilot
# 57: Claude, Gemini
# 58: several
# 59: ChatGPT, Copilot
# 61: Claude
# 62: Copilot
# 63: Claude, ChatGPT
# 64: Gemini
# 65: Microsoft Copilot, Devin
# 66: Chat gpt, claude
# 68: Claude, GitHubCopilot
